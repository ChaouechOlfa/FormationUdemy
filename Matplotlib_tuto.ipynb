# %% [markdown]
# <a href="https://colab.research.google.com/github/ChaouechOlfa/FormationUdemy/blob/main/Matplotlib_tuto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
#Les données à visualiser
prix_ms=[39,50,53,69,54,100]
prix_apple=[93,112,104,144,170,172]
annee=[2015,2016,2017,2018,2019,2020]

# %%
#Visualiser les données
plt.scatter(annee,prix_ms,label='prix Windows',c='r')
plt.plot(annee,prix_apple,label='prix Appel',c='g')
plt.legend()
plt.xlabel('Année')
plt.ylabel('Prix des ordinateurs')
# Out:
# Text(0, 0.5, 'Prix des ordinateurs')

# %%
#Visualiser les données dans deux plans
plt.subplot(2,1,1)
plt.scatter(annee,prix_ms,label='Prix Windows',c='lime')
plt.subplot(2,1,2)
plt.plot(annee,prix_apple,label='Prix Apple',c='r')

# %%
#Visualiser les données dans deux plans
plt.subplot(2,2,1)
plt.scatter(annee,prix_ms,label='Prix Windows',c='lime')
plt.subplot(2,2,4)
plt.plot(annee,prix_apple,label='Prix Apple',c='r')

# %%
#Visualiser les données en diagramme en barres
plt.bar(annee,prix_ms,label='prix Windows')
plt.xlabel('Annee')
plt.ylabel('prix des ordinateurs')
plt.legend()
plt.title('Evolution des ordinateurs durant les 5 denières années')
# Out:
# Text(0.5, 1.0, 'Evolution des ordinateurs durant les 5 denières années')

# %%
#Visualiser les deux diagrammes en bandes sur la même courbe
plt.bar(annee,prix_ms, label='Prix Windows')
plt.bar (annee, prix_apple,label='Prix Apple',bottom=prix_ms)
plt.legend()
plt.xlabel('Année')
plt.ylabel('Prix des Ordinateurs')
plt.title('Evolution des prix des ordinateurs durant les 5 dernières Années')
# Out:
# Text(0.5, 1.0, 'Evolution des prix des ordinateurs durant les 5 dernières Années')

# %%
index_annee=np.arange(len(annee))
a=0.25
plt.bar(index_annee,prix_ms,label='Prix Windows',width=0.25)
plt.bar(index_annee+a,prix_apple,label='Prix Apple',width=0.25)
plt.legend()
plt.xlabel('Année')
plt.ylabel('Prix de Ordinateurs')
plt.title('Evolution des prix des ordinateurs durant les 5 dernières années')
# Out:
# Text(0.5, 1.0, 'Evolution des prix des ordinateurs durant les 5 dernières années')

# %%
#Dessiner Pie Chart
produit=['P1','P2','P3','P4']
vente=[10,20,20,50]
plt.pie(vente,labels=produit,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f1e55a8c220>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, 'P1'),
#   Text(0.33991867422268784, 1.0461621742897658, 'P2'),
#   Text(-0.8899187180267095, 0.6465637441936395, 'P3'),
#   Text(5.149471664411206e-08, -1.0999999999999988, 'P4')],
#  [Text(0.5706339089091244, 0.1854101992962986, '10.0%'),
#   Text(0.1854101859396479, 0.5706339132489631, '20.0%'),
#   Text(-0.48541020983275057, 0.3526711331965306, '20.0%'),
#   Text(2.8088027260424755e-08, -0.5999999999999993, '50.0%')])
