# %% [markdown]
# <a href="https://colab.research.google.com/github/ChaouechOlfa/FormationUdemy/blob/main/Comment_connecter_son_google_drive_%C3%A0_google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Comment connecter son google drive à google collaboratory:
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls "/content/gdrive/MyDrive"
# Out:
#  2019
#  Anglais
# 'AUDIO BCT'
#  bur2017
#  BUREAU2021
#  bureau2021_2
#  Bureau_8.jpg
#  CDMaitreAssistant
# 'chap ii'
#  chapitreI
# 'Chapitre I.docx'
#  CHPI
#  Classroom
#  CNUDST
# 'Colab Notebooks'
# 'CorrectionSerie1 (1).zip'
# 'CorrectionSerie1 (2).zip'
#  CorrectionSerie1.zip
#  crud
# 'curr_vitae Achouri English.gdoc'
#  CV2019
#  CV2019.zip
#  Dérivées.pdf
#  DSI_3
# 'Election Presidentielle2019HammametRepublique.zip'
#  EPI
# 'Formulaire sans titre.gform'
#  FORUMM.ppt
#  IMG20200216231027.jpg
# 'Ma soutenance Nchallah.ppt'
# 'Ma soutenance.ppt'
# 'Meet Recordings'
#  MyRapportPFE
#  PHOTO2019
#  POURtirer
# 'pr tirage'
#  Scorarity
# 'SOUTENANCE (2).ppt'
#  sss
# 'THESE OLFA'
#  video-1530088519.mp4

# %%
cd "/content/gdrive/MyDrive/Colab Notebooks"
# Out:
# /content/gdrive/MyDrive/Colab Notebooks

# %%
ls
# Out:
# Boston-house.ipynb           Untitled0.ipynb
# ConnectDriveWithColab.ipynb  Untitled1.ipynb

# %%
mkdir Rappel

# %%
cd "/content/gdrive/MyDrive/Colab Notebooks/Rappel"
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/Rappel

# %%
pd.read_csv('student-mat.csv',sep=';')
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...
