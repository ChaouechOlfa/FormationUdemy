# %% [markdown]
# <a href="https://colab.research.google.com/github/ChaouechOlfa/FormationUdemy/blob/main/lireDesDonneesSurPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd "/content/gdrive/MyDrive/Colab Notebooks"
# Out:
# /content/gdrive/MyDrive/Colab Notebooks

# %%
mkdir FormationUdemy

# %%
cd "/content/gdrive/MyDrive/Colab Notebooks/FormationUdemy"
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/FormationUdemy

# %%
df=pd.read_csv('student-mat.csv',sep=';')

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Pour afficher la taille
df.shape
# Out:
# (395, 33)

# %%
#Afficher les noms des colonnes
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# ...

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
#Afficher uniquement une colonne
x=df['age']

# %%
x
# Out:
# 0      18
# 1      17
# 2      15
# 3      15
# 4      16
#        ..
# 390    20
# 391    17
# 392    21
# 393    18
# 394    19
# Name: age, Length: 395, dtype: int64

# %%
x.mean()
# Out:
# 16.696202531645568

# %%
x.describe()
# Out:
# count    395.000000
# mean      16.696203
# std        1.276043
# min       15.000000
# 25%       16.000000
# 50%       17.000000
# 75%       18.000000
# max       22.000000
# Name: age, dtype: float64

# %%
#construire une mini base à partir de notre base principale
x=df[['age','sex','studytime','G1']]

# %%
x
# Out:
#      age sex  studytime  G1
# 0     18   F          2   5
# 1     17   F          2   5
# 2     15   F          2   7
# 3     15   F          3  15
# 4     16   F          2   6
# ..   ...  ..        ...  ..
# 390   20   M          2   9
# 391   17   M          1  14
# 392   21   M          1  10
# 393   18   M          1  11
# 394   19   M          1   8
#
# [395 rows x 4 columns]

# %%
x['sex'].value_counts()
# Out:
# F    208
# M    187
# Name: sex, dtype: int64

# %%
x.describe()
# Out:
#               age   studytime          G1
# count  395.000000  395.000000  395.000000
# mean    16.696203    2.035443   10.908861
# std      1.276043    0.839240    3.319195
# min     15.000000    1.000000    3.000000
# 25%     16.000000    1.000000    8.000000
# 50%     17.000000    2.000000   11.000000
# 75%     18.000000    2.000000   13.000000
# max     22.000000    4.000000   19.000000

# %%
df['sex']
# Out:
# 0      F
# 1      F
# 2      F
# 3      F
# 4      F
#       ..
# 390    M
# 391    M
# 392    M
# 393    M
# 394    M
# Name: sex, Length: 395, dtype: object

# %%
df.iloc[4]
# Out:
# school            GP
# sex                F
# age               16
# address            U
# famsize          GT3
# Pstatus            T
# Medu               3
# Fedu               3
# Mjob           other
# Fjob           other
# reason          home
# guardian      father
# traveltime         1
# studytime          2
# failures           0
# schoolsup         no
# famsup           yes
# paid             yes
# activities        no
# nursery          yes
# higher           yes
# internet          no
# romantic          no
# famrel             4
# freetime           3
# goout              2
# Dalc               1
# Walc               2
# health             5
# absences           4
# G1                 6
# G2                10
# G3                10
# Name: 4, dtype: object

# %%
#Pour choisir un ensemble de lignes
df.iloc[10:20]
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 10     GP   F   15       U     GT3       T     4     4   teacher    health
# 11     GP   F   15       U     GT3       T     2     1  services     other
# 12     GP   M   15       U     LE3       T     4     4    health  services
# 13     GP   M   15       U     GT3       T     4     3   teacher     other
# 14     GP   M   15       U     GT3       A     2     2     other     other
# 15     GP   F   16       U     GT3       T     4     4    health     other
# 16     GP   F   16       U     GT3       T     4     4  services  services
# 17     GP   F   16       U     GT3       T     3     3     other     other
# 18     GP   M   17       U     GT3       T     3     2  services  services
# 19     GP   M   16       U     LE3       T     4     3    health     other
#
#     ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 10  ...      3        3      3     1     2      2        0  10   8   9
# ...

# %%
#Si on veut choisir seulement une colonne précise 
df.iloc[10:20,[1]]
# Out:
#    sex
# 10   F
# 11   F
# 12   M
# 13   M
# 14   M
# 15   F
# 16   F
# 17   F
# 18   M
# 19   M

# %%
df.iloc[10:20,[1,3,5]]
# Out:
#    sex address Pstatus
# 10   F       U       T
# 11   F       U       T
# 12   M       U       T
# 13   M       U       T
# 14   M       U       A
# 15   F       U       T
# 16   F       U       T
# 17   F       U       T
# 18   M       U       T
# 19   M       U       T

# %%
df.loc[10:20]
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 10     GP   F   15       U     GT3       T     4     4   teacher    health
# 11     GP   F   15       U     GT3       T     2     1  services     other
# 12     GP   M   15       U     LE3       T     4     4    health  services
# 13     GP   M   15       U     GT3       T     4     3   teacher     other
# 14     GP   M   15       U     GT3       A     2     2     other     other
# 15     GP   F   16       U     GT3       T     4     4    health     other
# 16     GP   F   16       U     GT3       T     4     4  services  services
# 17     GP   F   16       U     GT3       T     3     3     other     other
# 18     GP   M   17       U     GT3       T     3     2  services  services
# 19     GP   M   16       U     LE3       T     4     3    health     other
# 20     GP   M   15       U     GT3       T     4     3   teacher     other
#
# ...

# %%
df.loc[10:20,['sex','G1']]
# Out:
#    sex  G1
# 10   F  10
# 11   F  10
# 12   M  14
# 13   M  10
# 14   M  14
# 15   F  14
# 16   F  13
# 17   F   8
# 18   M   6
# 19   M   8
# 20   M  13

# %%
#Opération de filtrage
sex_filt=(df['sex']=='F')

# %%
df[sex_filt]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# 386     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
#
# ...

# %%
df.loc[sex_filt,'G1']
# Out:
# 0       5
# 1       5
# 2       7
# 3      15
# 4       6
#        ..
# 385    10
# 386     6
# 387     7
# 388     7
# 389     6
# Name: G1, Length: 208, dtype: int64

# %%
#Afficher les notes des filles qui travaillent 2 heures
sex_filt=((df['sex']=='F')&(df['studytime'] ==2))

# %%
sex_filt
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# Length: 395, dtype: bool

# %%
df.loc[sex_filt,['sex','studytime','age','G1']]
# Out:
#     sex  studytime  age  G1
# 0     F          2   18   5
# 1     F          2   17   5
# 2     F          2   15   7
# 4     F          2   16   6
# 7     F          2   17   6
# ..   ..        ...  ...  ..
# 377   F          2   18   8
# 378   F          2   18  15
# 379   F          2   17  10
# 388   F          2   18   7
# 389   F          2   18   6
#
# [113 rows x 4 columns]

# %%
sex_filt=(df['sex']=='F')
df.loc[sex_filt,['sex','studytime','age','G1']]
# Out:
#     sex  studytime  age  G1
# 0     F          2   18   5
# 1     F          2   17   5
# 2     F          2   15   7
# 3     F          3   15  15
# 4     F          2   16   6
# ..   ..        ...  ...  ..
# 385   F          3   18  10
# 386   F          1   18   6
# 387   F          3   19   7
# 388   F          2   18   7
# 389   F          2   18   6
#
# [208 rows x 4 columns]

# %%
df.loc[-sex_filt,['sex','studytime','age','G1']]
# Out:
#     sex  studytime  age  G1
# 5     M          2   16  15
# 6     M          2   16  12
# 8     M          2   15  16
# 9     M          2   15  14
# 12    M          1   15  14
# ..   ..        ...  ...  ..
# 390   M          2   20   9
# 391   M          1   17  14
# 392   M          1   21  10
# 393   M          1   18  11
# 394   M          1   19   8
#
# [187 rows x 4 columns]

# %%
df['ParentJobs']=df['Mjob']+' '+df['Fjob']

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   Dalc Walc  health  absences  G1  G2  G3         PrentJob        ParentJob  \
# 0    1    1       3         6   5   6   6  at_home teacher  at_home teacher
# 1    1    1       3         4   5   5   6    at_home other    at_home other
# 2    2    3       3        10   7   8  10    at_home other    at_home other
# 3    1    1       5         2  15  14  15  health services  health services
# 4    1    2       5         4   6  10  10      other other      other other
#
#         ParentJobs
# 0  at_home teacher
# ...

# %%
df.drop(columns=['ParentJobs'],inplace=True)

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   Dalc Walc  health  absences  G1  G2  G3         PrentJob        ParentJob  \
# 0    1    1       3         6   5   6   6  at_home teacher  at_home teacher
# 1    1    1       3         4   5   5   6    at_home other    at_home other
# 2    2    3       3        10   7   8  10    at_home other    at_home other
# 3    1    1       5         2  15  14  15  health services  health services
# 4    1    2       5         4   6  10  10      other other      other other
#
#         ParentJobs
# 0  at_home teacher
# ...

# %%
df['Coef_x']=df['traveltime']+df['studytime']+df['failures']

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   Dalc Walc  health  absences  G1  G2  G3         PrentJob        ParentJob  \
# 0    1    1       3         6   5   6   6  at_home teacher  at_home teacher
# 1    1    1       3         4   5   5   6    at_home other    at_home other
# 2    2    3       3        10   7   8  10    at_home other    at_home other
# 3    1    1       5         2  15  14  15  health services  health services
# 4    1    2       5         4   6  10  10      other other      other other
#
#   Coef_x
# 0      4
# 1      3
# ...

# %%
df.drop(columns=['Coef_x','absences'],inplace=True)

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health  G1  G2  G3         PrentJob  \
# 0        3     4     1     1       3   5   6   6  at_home teacher
# 1        3     3     1     1       3   5   5   6    at_home other
# 2        3     2     2     3       3   7   8  10    at_home other
# 3        2     2     1     1       5  15  14  15  health services
# 4        3     2     1     2       5   6  10  10      other other
#
#          ParentJob
# 0  at_home teacher
# 1    at_home other
# 2    at_home other
# ...

# %%
#Calcul de la moyenne générale 
df['G1'].mean()
# Out:
# 10.90886075949367

# %%
df['G3'].median()
# Out:
# 11.0

# %%
df['G3'].max()
# Out:
# 20

# %%
df['studytime'].value_counts()
# Out:
# 2    198
# 1    105
# 3     65
# 4     27
# Name: studytime, dtype: int64

# %%
study_grp=df.groupby(['studytime'])

# %%
study_grp.get_group(4)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 47      GP   M   16       U     GT3       T     4     3    health  services
# 66      GP   M   15       U     GT3       A     4     4     other  services
# 67      GP   F   16       U     GT3       T     3     1  services     other
# 69      GP   F   15       R     LE3       T     3     1     other     other
# 70      GP   M   16       U     GT3       T     3     1     other     other
# 71      GP   M   15       U     GT3       T     4     2     other     other
# 76      GP   M   15       U     GT3       T     4     0   teacher     other
# 77      GP   F   16       U     GT3       T     2     2     other     other
# 94      GP   M   15       U     LE3       T     2     2  services    health
# 95      GP   F   15       R     GT3       T     1     1   at_home     other
# 105     GP   F   15       U     GT3       A     3     3     other    health
# ...

# %%
df['studytime']
# Out:
# 0      2
# 1      2
# 2      2
# 3      3
# 4      2
#       ..
# 390    2
# 391    1
# 392    1
# 393    1
# 394    1
# Name: studytime, Length: 395, dtype: int64

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health  G1  G2  G3         PrentJob  \
# 0        3     4     1     1       3   5   6   6  at_home teacher
# 1        3     3     1     1       3   5   5   6    at_home other
# 2        3     2     2     3       3   7   8  10    at_home other
# 3        2     2     1     1       5  15  14  15  health services
# 4        3     2     1     2       5   6  10  10      other other
#
#          ParentJob
# 0  at_home teacher
# 1    at_home other
# 2    at_home other
# ...
